# %% [markdown]
# ### Backpropagation

# %% [markdown]
# ![image.png](attachment:dbafeead-1e70-4e59-bca1-6fa3c38b6cca.png)

# %% [markdown]
# ![image.png](attachment:704ef830-7d82-41e9-b04b-d44d47366942.png)
