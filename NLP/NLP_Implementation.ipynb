# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Restaurant_Reviews.tsv', delimiter = '\t', quoting = 3)
# TSV - Tab seperated values

# %% [markdown]
# ## Importing Libraries

# %%
import re 
# re - used to define and apply complex search patterns to solve various text processing tasks.
import nltk 
from nltk.corpus import stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
print(stopwords)
# Out:
# <WordListCorpusReader in '.../corpora/stopwords' (not loaded yet)>

# %%
# This is the preprocessing of the data

corpus = []

for i in range(0,1000):
    zomato_ratings = re.sub('[^a-zA-z]', ' ', dataset['Review'][i])
    zomato_ratings = zomato_ratings.lower()
    zomato_ratings = zomato_ratings.split()

    ps = PorterStemmer() # check what it does
    all_stopwords = stopwords.words('english')
    all_stopwords.removep['not']
    zomato_reviews = [ ps.stem(word) for word in zomato_ratings if not word in set(all_stopwords)]
    zomato_reviews = ''.join(zomato_ratings)
    corpus.append(zomato_ratings)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 10
#       7 zomato_ratings = zomato_ratings.lower()
#       8 zomato_ratings = zomato_ratings.split()
# ---> 10 ps = PorterStemmer() # check what it does
#      11 all_stopwords = stopwords.words('english')
#      12 all_stopwords.removep['not']
#
# NameError: name 'PorterStemmer' is not defined

# %% [markdown]
# ## Bag of words creation
