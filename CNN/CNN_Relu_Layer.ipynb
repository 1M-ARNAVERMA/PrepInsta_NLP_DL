# %% [markdown]
# ![image.png](attachment:f26847f4-3808-4505-b353-79a2f5356b1f.png)

# %% [markdown]
# ![image.png](attachment:ea9ca64b-ab2b-4ab1-b7c0-c67e018c02dd.png)

# %% [markdown]
# ![image.png](attachment:97d1ac46-64ae-4f20-bf32-a6a4a1251856.png)
